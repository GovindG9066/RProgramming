# %%
# Assignment No 3

# %%
# Write a Program to implement Data cleaning -find all null values/missing values
# in a given dataset and remove them. [use diabetes_null_values dataset] ]

# %%
import pandas as pd
df=pd.read_csv('diabetes_null_values.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72           35.0      0.0  33.6
# 1              1       85             66           29.0      NaN  26.6
# 2              8      183             64            NaN      0.0  23.3
# 3              1       89             66           23.0     94.0  28.1
# 4              0      137             40           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76           48.0    180.0  32.9
# 764            2      122             70           27.0      0.0  36.8
# 765            5      121             72           23.0    112.0  26.2
# 766            1      126             60            0.0      0.0  30.1
# 767            1       93             70           31.0      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
null_row=df.isnull()
print("The NUll rows are : /n",null_row)
# Out:
# The NUll rows are : /n      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False     True  False
# 2          False    False          False           True    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# ...

# %%
Remove_row=df.dropna()
print("The after remove the null rows : /n",Remove_row)
# Out:
# The after remove the null rows : /n      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72           35.0      0.0  33.6
# 3              1       89             66           23.0     94.0  28.1
# 4              0      137             40           35.0    168.0  43.1
# 5              5      116             74            0.0      0.0  25.6
# 6              3       78             50           32.0     88.0  31.0
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76           48.0    180.0  32.9
# 764            2      122             70           27.0      0.0  36.8
# 765            5      121             72           23.0    112.0  26.2
# 766            1      126             60            0.0      0.0  30.1
# 767            1       93             70           31.0      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...
